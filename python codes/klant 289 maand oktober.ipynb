# %%
# Import Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Data
data = pd.read_csv('/datc/parcel/notebooks/data/postnl/20201014_300_klanten.csv', parse_dates=[0])

# %%
data
# Out:
#         procesdag    cust_id  aantal_pakketten  aantal_pakketten_volgende_dag  \
# 0      2015-01-02    klant_1                 0                              0
# 1      2015-01-02  klant_100                 0                              0
# 2      2015-01-02  klant_101                 0                              0
# 3      2015-01-02  klant_103                 0                              0
# 4      2015-01-02  klant_104                 0                              0
# ...           ...        ...               ...                            ...
# 505695 2020-04-29   klant_95                68                             60
# 505696 2020-04-29   klant_96                 0                              0
# 505697 2020-04-29   klant_97                66                            123
# 505698 2020-04-29   klant_98              2035                           2133
# 505699 2020-04-29   klant_99               145                            121
#
#        validation_column
# ...

# %%
# Manipulate Data
cust_filter = data['cust_id'] == 'klant_289'
date_filter = data['procesdag'].dt.dayofweek <= 4
data = data.where(date_filter & cust_filter).dropna()

# %%
data
# Out:
#         procesdag    cust_id  aantal_pakketten  aantal_pakketten_volgende_dag  \
# 183    2015-01-02  klant_289             168.0                            0.0
# 963    2015-01-05  klant_289             183.0                          208.0
# 1223   2015-01-06  klant_289             208.0                          202.0
# 1483   2015-01-07  klant_289             202.0                          206.0
# 1743   2015-01-08  klant_289             206.0                          153.0
# ...           ...        ...               ...                            ...
# 504063 2020-04-23  klant_289             149.0                          147.0
# 504323 2020-04-24  klant_289             147.0                            0.0
# 505103 2020-04-27  klant_289               0.0                          227.0
# 505363 2020-04-28  klant_289             227.0                          173.0
# 505623 2020-04-29  klant_289             173.0                          295.0
#
#        validation_column
# ...

# %%
y = data.aantal_pakketten_volgende_dag
X = data[['procesdag', 'aantal_pakketten']]

# %%
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data['procesdag'], data['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 69')
plt.grid()
plt.show()

# %%
data = data.set_index(data.procesdag, drop=True)

# %% [markdown]
# # DATA PER JAAR

# %%
data_2015 = data['2015-01-01':'2016-01-01']

# %%
# 2015
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2015['procesdag'], data_2015['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 69')
plt.grid()
plt.show()

# %%
data_2016 = data['2016-01-01':'2017-01-01']

# %%
# 2016
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2016['procesdag'], data_2016['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 69')
plt.grid()
plt.show()

# %%
data_2017 = data['2017-01-01':'2018-01-01']

# %%
# 2017
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2017['procesdag'], data_2017['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 69')
plt.grid()
plt.show()

# %%
data_2018 = data['2018-01-01':'2019-01-01']

# %%
# 2018
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2018['procesdag'], data_2018['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 69')
plt.grid()
plt.show()

# %%
data_2019 = data['2019-01-01':'2020-01-01']

# %%
# 2019
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2019['procesdag'], data_2019['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 69')
plt.grid()
plt.show()

# %% [markdown]
# # DATA AUGUSTUS PER JAAR

# %%
#Augustus 2015
data_2015_augustus = data_2015['2015-08-01':'2015-09-01']

# %%
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2015_augustus['procesdag'], data_2015_augustus['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 289')
plt.grid()
plt.show()

# %%
#Augustus 2016
data_2016_augustus = data_2016['2016-08-01':'2016-09-01']

# %%
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2016_augustus['procesdag'], data_2016_augustus['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 289')
plt.grid()
plt.show()

# %%
#Augustus 2017
data_2017_augustus = data_2017['2017-08-01':'2017-09-01']

# %%
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2017_augustus['procesdag'], data_2017_augustus['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 289')
plt.grid()
plt.show()

# %%
#Augustus 2018
data_2018_augustus = data_2018['2018-08-01':'2018-09-01']

# %%
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2018_augustus['procesdag'], data_2018_augustus['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 289')
plt.grid()
plt.show()

# %%
#Augustus 2019
data_2019_augustus = data_2019['2019-08-01':'2019-09-01']

# %%
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(data_2019_augustus['procesdag'], data_2019_augustus['aantal_pakketten'])
plt.xlabel = ('Procesdag')
plt.ylabel = ('Aantal Pakketten')
plt.title = ('Aantal Pakketten Klant 289')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-326-ae121e0878f8> in <module>
#       1 fig, ax = plt.subplots(figsize = (15, 10))
# ----> 2 plt.plot(data_2019_augustus['procesdag'], data_2019_augustus['aantal_pakketten'])
#       3 plt.xlabel = ('Procesdag')
#       4 plt.ylabel = ('Aantal Pakketten')
#       5 plt.title = ('Aantal Pakketten Klant 289')
#
# NameError: name 'data_2019_augustus' is not defined
